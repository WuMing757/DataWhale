# %%
# !type task3_example.xlsx
# Out:
# _rels/.rels �(�瑨MO�0嗭H鼑洒蛰�BKwAH�!T~�I�祶�$菘'T�G絶�售�<嶊�!鲡4瑡;#秝瓎楘qu*&r朏q�崮v挣睁橤Jy(v綇*�辅�K蛇#F玉D��.W	��=檨Z芃Y辀��誃S憝啺�7犼撓�讝﹂
# 炻�
# ;侂蚔%�R(敝眙み膹]愠磑s�>だ憀菎咷V2� �鑸澙胞蟞J�珪掲A答韧C抽�炀/]嬙鮳R�
# dD镋�5�4偐爻�D%泎摒�幖	rf莚緫纉&o$�z�3a墉寚遠i聋*�
# 卉��	慹�%�P�?VT气�9L桝�F�?煠v0圅誼泊}淾E嫅镂疓/�臫怓绡���_\逪;x�7<;褁v_/圬?喠鱞�1鳛辰:n�V�阔L�dc�:淥鳚髞g:囂M�>樽�0旧�1莊6�t�(�-岵蚿迫鶏R�"�Zg�獡踔�
# b憝侴礻氆�歴�>捜,�8骧(%嚕�"D艄覇4j�0u2js�蔒Y匏翠�鷦S飙偞贩 �)f��笴埚焸y洋	I<
# 蓈摆&ZuZU浇;f VS酃���{前�,i�t�勜3�9g<饣cU�=h#U漃闝礟櫖媱~��0yG壉嘉x﹋H�z椌}斵�
# �%圥泟n琺"茖谸磐T5Pc&W衡泛`ρ莱靓猟佺-X舉M;凥_儭騖
# X)鲍牰垎抂詏6�1=Z%畞�皋顨塒U�kYJ�詡RR夎报曟��>�!洙�鄌钟瘩�J
# 瓕薯慪��昌[v烁�.��
# �檰絫<A瘬湎��6{%豣s钎�澨�藍﨤疬w飔閟縤g'旌"騽摞�2�,峓�鼝p0gkb��+� , 嘜壋鏩┉+|膼噲�-p圽X箛%攅B?-嗅?[\"巫=跜k柘歞愺]i卡�惻�"�踭>壊��E鈏0d�稿i�諄喟Q�i竰t��衉風c醞锉�v監儤鞶歺谓?蟳/s梭�?�Jt啶�讈艃庂HG些K杪骃�;v~=;灬坿植掀靅8�{�?靀<跋G靉祟徛柝v`c鑫b�^繥�YRB轟鎲輞蕸廒����礦知�適饈
# �;綢步�l貼陟&!毪鋛l彮蓭4F3迧	亽<酯PHK_
# }隒)
# ...

# %%
import pandas as pd

# %%
pd.read_excel('task3_example.xlsx',header=None)
# Out:
#         0     1      2
# 0   stock  open  close
# 1  huawei    20     50
# 2   apple    30     40
# 3  banana    15     20

# %%
pd.read_excel('task3_example.xlsx')
# Out:
#     stock  open  close
# 0  huawei    20     50
# 1   apple    30     40
# 2  banana    15     20

# %%
name = ['a','b','c','d']

# %%
pd.read_excel('task3_example.xlsx',names=name[:-1])
# Out:
#         a   b   c
# 0  huawei  20  50
# 1   apple  30  40
# 2  banana  15  20

# %%
pd.read_excel('task3_example.xlsx',index_col='stock')
# Out:
#         open  close
# stock
# huawei    20     50
# apple     30     40
# banana    15     20

# %%
pd.read_excel('task3_example.xlsx')
# Out:
#     stock open  close
# 0  huawei   20     50
# 1   apple   30     40
# 2  banana   15     20
# 3    none   30     50
# 4   grape   na     20

# %%
# 'task3_example.xlsx'
sentinels = {'stock':['none'], 'open':['na']}
pd.read_excel('task3_example.xlsx',na_values=sentinels )
# Out:
#     stock  open  close
# 0  huawei  20.0     50
# 1   apple  30.0     40
# 2  banana  15.0     20
# 3     NaN  30.0     50
# 4   grape   NaN     20

# %%
# 读取大文件
pd.read_excel('task3_example.xlsx',nrows=2)
# Out:
#     stock  open  close
# 0  huawei    20     50
# 1   apple    30     40

# %%
import sys# 打印结果
data = pd.read_excel('task3_example.xlsx')
data.to_csv(sys.stdout, sep='|')
# Out:
# |stock|open|close
# 0|huawei|20|50
# 1|apple|30|40
# 2|banana|15|20
# 3|none|30|50
# 4|grape|na|20

# %%
# 二进制数据格式
# pd.to_pickle

# 大规模数据
# pd.HDFStore
